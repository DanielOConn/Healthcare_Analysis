# %% [markdown]
# Scope of the project:
# Find the average age of patients
# Find out number of patients in in each region
# Plot cost against age - find the gradient
# Plot cost against bmi - find the gradient
# Find number/percentage of patients in low bmi/healthy/overweight ranges?
# Is bmi related to age? correlation?
# analyse cost of smoker v non-smokers (average increase?)

# %%
import csv

with open("insurance.csv") as ins_csv:
    
    mother_list = []
    
    for line in ins_csv:
        mother_list.append(line)
        
    split_list = []
    
    for item in mother_list:
        item_split = item.split(",")
        split_list.append(item_split)
        
    age = []
    sex = []
    bmi = []
    children = []
    smoker = []
    region = []
    charges = []
    
    for item in split_list:
        age.append(item[0])
        sex.append(item[1])
        bmi.append(item[2])
        children.append(item[3])
        smoker.append(item[4])
        region.append(item[5])
        charges.append(item[6])
        
    age.pop(0)
    sex.pop(0)
    bmi.pop(0)
    children.pop(0)
    smoker.pop(0)
    region.pop(0)
    charges.pop(0)

#print(age)



def average_age(ages_list):
    total_age = 0
    for i in range(len(ages_list)):
        if i == 0:
            pass
        elif i > 0:
            total_age += int(ages_list[i])
    average_age = total_age/(len(ages_list)-1)
    return average_age
    

print(average_age(age))

# following code will make a dictionary of regions to how many times the occur. Problem could be that the list are all made of strings?
# Could make lists of numbers. Would python then organise in numerical order?

region_keys = []

for reg in region:
    if reg == "region":
        pass
    elif reg in region_keys:
        pass
    elif reg not in region_keys:
        region_keys.append(reg)

float_age = []

for each in age:
    float_age.append(float(each))
    
float_bmi = []

for each_bmi in bmi:
    float_bmi.append(float(each_bmi))
        
#print(region_keys)

region_dictionary = {'southwest': region.count('southwest'), 'southeast': region.count('southeast'), 'northwest': region.count('northwest'), 'northeast': region.count('northeast')}

print(region_dictionary)

print(region.count('southeast'))

#print(len(region))

import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')

import numpy as np

plt.rcParams['figure.figsize'] = [15, 15]

plt.plot(float_age, float_bmi, 'o', color = 'grey')

plt.title('Age versus BMI')
plt.ylabel('BMI')
plt.xlabel('Age')

#This code doesnt organise the graph in order

class Gender_Analysis:
    def __init__(self,sex,charges):
        self.sex = sex
        self.charges = charges
        
    def gender_cost(self):
        females = 0
        males = 0
        for person in sex:
            if person == "male":
                males += 1
            elif person == "female":
                females += 1
        total_male_cost = 0
        total_female_cost = 0
        for position in range(len(sex)):
            if sex[position] == "male":
                total_male_cost += float(charges[position])
            elif sex[position] == "female":
                total_female_cost += float(charges[position])
        average_males_cost = total_male_cost/males
        average_females_cost = total_female_cost/females
        print("The average cost for a male is " + str(average_males_cost) + " dollars. The average cost for a female is " + str(average_females_cost) + " dollars.")

analyse_gender = Gender_Analysis(sex, charges)

analyse_gender.gender_cost()

print(bmi)
# Out:
# 39.222139117427076
# {'southwest': 325, 'southeast': 364, 'northwest': 325, 'northeast': 324}
# 364
# The average cost for a male is 13956.751177721886 dollars. The average cost for a female is 12569.57884383534 dollars.
# ...
